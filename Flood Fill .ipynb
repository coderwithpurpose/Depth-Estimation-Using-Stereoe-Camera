# %%
import numpy as np 
def floodfill(matrix, x, y):
    global l 
    #"hidden" stop clause - not reinvoking for "c" or "b", only for "a".
    if matrix[x][y] == "a":   
        l+=1
        matrix[x][y] = "c" 
        #recursively invoke flood fill on all surrounding cells:
        if x > 0: # go up 1 
            floodfill(matrix,x-1,y)
        if x < len(matrix) - 1: # go down 1 
            floodfill(matrix,x+1,y)
        if y > 0: #### go right one 
            floodfill(matrix,x,y-1)
        if y < len(matrix[y]) - 1: ### go left one 
            floodfill(matrix,x,y+1) 
            
        if x < len(matrix) - 1 and y < len(matrix) - 1: # go down 1 
            floodfill(matrix,x+1,y+1)
        if x >0 and y < len(matrix[y]) - 1: # go down 1 
            floodfill(matrix,x-1,y+1)
        if y > 0 and x > 0: # go down 1 
            floodfill(matrix,x-1,y-1)
        if y > 0 and x < len(matrix) - 1: # go down 1 
            floodfill(matrix,x+1,y-1)

# %%
matrix = [["a", "a", "b", "a", "a", "b"],
          ["a", "b", "b", "a", "b", "b"],
          ["b", "a", "b", "a", "a", "b"],
          ["b", "a", "b", "a", "b", "b"],
          ["a", "a", "b", "a", "a", "a"]]
l=0 
# x,y = np.shape(matrix) 
# print(x,y,len(matrix[0]))
floodfill(matrix,3,3)  
print(l) 
(matrix)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-68c8c3d7bb0f> in <module>()
#       7 # x,y = np.shape(matrix)
#       8 # print(x,y,len(matrix[0]))
# ----> 9 floodfill(matrix,3,3)
#      10 print(l)
#      11 (matrix)
#
# <ipython-input-59-fa53c78dc105> in floodfill(matrix, x, y)
#      11             floodfill(matrix,x-1,y)
#      12         if x < len(matrix) - 1: # go down 1
# ---> 13             floodfill(matrix,x+1,y)
#      14         if y > 0: #### go right one
#      15             floodfill(matrix,x,y-1)
#
# <ipython-input-59-fa53c78dc105> in floodfill(matrix, x, y)
#      15             floodfill(matrix,x,y-1)
#      16         if y < len(matrix[y]) - 1: ### go left one
# ---> 17             floodfill(matrix,x,y+1)
#      18
#      19         if x < len(matrix) - 1 and y < len(matrix) - 1: # go down 1
#
# <ipython-input-59-fa53c78dc105> in floodfill(matrix, x, y)
#      15             floodfill(matrix,x,y-1)
#      16         if y < len(matrix[y]) - 1: ### go left one
# ---> 17             floodfill(matrix,x,y+1)
#      18
#      19         if x < len(matrix) - 1 and y < len(matrix) - 1: # go down 1
#
# <ipython-input-59-fa53c78dc105> in floodfill(matrix, x, y)
#      14         if y > 0: #### go right one
#      15             floodfill(matrix,x,y-1)
# ---> 16         if y < len(matrix[y]) - 1: ### go left one
#      17             floodfill(matrix,x,y+1)
#      18
#
# IndexError: list index out of range

# %%
matrix
# Out:
# [['c', 'c', 'b', 'a', 'a', 'b'],
#  ['c', 'b', 'b', 'a', 'b', 'b'],
#  ['b', 'c', 'b', 'a', 'a', 'b'],
#  ['b', 'c', 'b', 'a', 'b', 'b'],
#  ['c', 'c', 'b', 'a', 'a', 'a'],
#  ['c', 'b', 'b', 'a', 'a', 'b']]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2  

img = cv2.imread('outdoor_may24/006.png')  
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
